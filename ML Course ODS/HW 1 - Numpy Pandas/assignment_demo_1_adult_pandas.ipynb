# %%
import Data as dt #мое творение...
import numpy as np
import pandas as pd

# %%
data = dt.Data_Analysis()
data.data_read(name_file='../data/adult.data.csv',r = ',',read_name_data = True)
#type(data)
data_pd = pd.read_csv('../data/adult.data.csv')

# %%
data.name_data
# Out:
# ['age',
#  'workclass',
#  'fnlwgt',
#  'education',
#  'education-num',
#  'marital-status',
#  'occupation',
#  'relationship',
#  'race',
#  'sex',
#  'capital-gain',
#  'capital-loss',
#  'hours-per-week',
#  'native-country',
#  'salar']

# %%
data.head(5)
data_pd.head()
# Out:
# ['39', 'State-gov', '77516', 'Bachelors', '13', 'Never-married', 'Adm-clerical', 'Not-in-family', 'White', 'Male', '2174', '0', '40', 'United-States', '<=50']
# ['50', 'Self-emp-not-inc', '83311', 'Bachelors', '13', 'Married-civ-spouse', 'Exec-managerial', 'Husband', 'White', 'Male', '0', '0', '13', 'United-States', '<=50']
# ['38', 'Private', '215646', 'HS-grad', '9', 'Divorced', 'Handlers-cleaners', 'Not-in-family', 'White', 'Male', '0', '0', '40', 'United-States', '<=50']
# ['53', 'Private', '234721', '11th', '7', 'Married-civ-spouse', 'Handlers-cleaners', 'Husband', 'Black', 'Male', '0', '0', '40', 'United-States', '<=50']
# ['28', 'Private', '338409', 'Bachelors', '13', 'Married-civ-spouse', 'Prof-specialty', 'Wife', 'Black', 'Female', '0', '0', '40', 'Cuba', '<=50']
#    age         workclass  fnlwgt  education  education-num  \
# 0   39         State-gov   77516  Bachelors             13
# 1   50  Self-emp-not-inc   83311  Bachelors             13
# ...

# %%
data.info()
# Out:
# Длина Базы Данных = 32562
# Количество признаков(столбцов/Data Frame) в Базе Данных = 15

# %%
data.test_err_data(data.test_inf) 
#Создает массив уникальных значений - на самом деле проверяет всю бд на исключения и отклонения от уникальных значений
#,но она пока что отключена

# %% [markdown]
# # <center>Вопросы к БД</center>

# %% [markdown]
# # 1.Сколько мужчин и женщин представленно в этой выборке?

# %%
data.head_sl(9)
# Out:
# Male  :  21790
# Female  :  10771
# 2

# %%
data_pd['sex'].value_counts()
# Out:
# Male      21790
# Female    10771
# Name: sex, dtype: int64

# %% [markdown]
# 10771

# %% [markdown]
# # 3. Какова доля граждан Германии (признак native-country)?

# %%
# групповой запрос, пока что не реализован

# %%
data.head_sl(13)
# Out:
# United-States  :  29170
# Cuba  :  95
# Jamaica  :  81
# India  :  100
# ?  :  583
# Mexico  :  643
# South  :  80
# Puerto-Rico  :  114
# Honduras  :  13
# England  :  90
# Canada  :  121
# Germany  :  137
# Iran  :  43
# Philippines  :  198
# Italy  :  73
# Poland  :  60
# Columbia  :  59
# Cambodia  :  19
# Thailand  :  18
# Ecuador  :  28
# Laos  :  18
# Taiwan  :  51
# Haiti  :  44
# Portugal  :  37
# Dominican-Republic  :  70
# El-Salvador  :  106
# France  :  29
# Guatemala  :  64
# China  :  75
# Japan  :  62
# Yugoslavia  :  16
# Peru  :  31
# Outlying-US(Guam-USVI-etc)  :  14
# Scotland  :  12
# Trinadad&Tobago  :  19
# Greece  :  29
# Nicaragua  :  34
# Vietnam  :  67
# Hong  :  20
# Ireland  :  24
# Hungary  :  13
# Holand-Netherlands  :  1
# 42

# %%
data.zapros_in_data("%:'Germany'",data.id_array_individual[13])
# Out:
# 0.4207358270376512

# %%
float((data_pd['native-country'] == 'Germany').sum()) / data_pd.shape[0]
# Out:
# 0.004207487485028101

# %% [markdown]
# 0.42

# %% [markdown]
# # 9. Какое максимальное число часов человек работает в неделю (признак hours-per-week)? Сколько людей работают такое количество часов и каков среди них процент зарабатывающих много?

# %%
data.head_sl(12)
# Out:
# 40  :  15217
# 13  :  23
# 16  :  205
# 45  :  1824
# 50  :  2819
# 80  :  133
# 30  :  1149
# 35  :  1297
# 60  :  1475
# 20  :  1224
# 52  :  138
# 44  :  212
# 15  :  404
# 25  :  674
# 38  :  476
# 43  :  151
# 55  :  694
# 48  :  517
# 58  :  28
# 32  :  266
# 70  :  291
# 2  :  32
# 22  :  44
# 56  :  97
# 41  :  36
# 28  :  86
# 36  :  220
# 24  :  252
# 46  :  82
# 42  :  219
# 12  :  173
# 65  :  244
# 1  :  20
# 10  :  278
# 34  :  28
# 75  :  66
# 98  :  11
# 33  :  39
# 54  :  41
# 8  :  145
# 6  :  64
# 64  :  14
# 19  :  14
# 18  :  75
# 72  :  71
# 5  :  60
# 9  :  18
# 47  :  49
# 37  :  149
# 21  :  24
# 26  :  30
# 14  :  34
# 4  :  54
# 59  :  5
# 7  :  26
# 99  :  85
# 53  :  25
# 39  :  38
# 62  :  18
# 57  :  17
# 78  :  8
# 90  :  29
# 66  :  17
# 11  :  11
# 49  :  29
# 84  :  45
# 3  :  39
# 17  :  29
# 68  :  12
# 27  :  30
# 85  :  13
# 31  :  5
# 51  :  13
# 77  :  6
# 63  :  10
# 23  :  21
# 87  :  1
# 88  :  2
# 73  :  2
# 89  :  2
# 97  :  2
# 94  :  1
# ...

# %%
data.zapros_in_data("max:'01'",data.id_array_individual[12])
# Out:
# 'Max = 99 - 85'

# %%
max_load = data_pd['hours-per-week'].max()
print("Самая большая загрузка - {0} час./нед.".format(max_load))

num_workaholics = data_pd[data_pd['hours-per-week'] == max_load].shape[0]
print("Всего таких работяг {0}".format(num_workaholics))

rich_share = float(data_pd[(data_pd['hours-per-week'] == max_load)
                 & (data_pd['salary'] == '>50K')].shape[0]) / num_workaholics
print("Из них богатых {0}%".format(int(100 * rich_share)))
# Out:
# Самая большая загрузка - 99 час./нед.
# Всего таких работяг 85
# Из них богатых 29%

# %% [markdown]
# 99  :  85

# %% [markdown]
# # 2. Каков средний возраст (признак age) женщин?

# %%
data.head_sl(9)
# Out:
# Male  :  21790
# Female  :  10771
# 2

# %%
data.zapros_in_data("k:'0'",data.id_array_individual[9]['Female'])
# Out:
# {'28': (310,
#   [[4, 9],
#    [66, 9],
#    [92, 9],
#    [113, 9],
#    [130, 9],
#    [163, 9],
#    [401, 9],
#    [408, 9],
#    [525, 9],
#    [781, 9],
#    [892, 9],
#    [971, 9],
#    [1157, 9],
#    [1272, 9],
#    [1311, 9],
#    [1472, 9],
#    [1637, 9],
#    [1932, 9],
#    [1967, 9],
#    [1987, 9],
#    [2001, 9],
#    [2084, 9],
#    [2130, 9],
#    [2518, 9],
#    [2639, 9],
#    [2649, 9],
#    [2725, 9],
#    [2838, 9],
#    [2853, 9],
#    [2857, 9],
#    [2881, 9],
#    [2928, 9],
#    [2984, 9],
#    [3586, 9],
#    [3729, 9],
#    [4002, 9],
#    [4037, 9],
#    [4084, 9],
#    [4142, 9],
#    [4294, 9],
#    [4340, 9],
#    [4528, 9],
#    [4835, 9],
#    [4939, 9],
#    [4961, 9],
#    [5003, 9],
#    [5123, 9],
#    [5208, 9],
#    [5304, 9],
#    [5338, 9],
#    [5452, 9],
#    [5502, 9],
#    [5591, 9],
#    [5616, 9],
#    [5720, 9],
#    [6143, 9],
#    [6162, 9],
#    [6398, 9],
#    [6521, 9],
#    [6650, 9],
#    [6726, 9],
#    [6772, 9],
# ...

# %%
data.zapros_in_data("p:'0'",data.zapros_data["k:'0'"])
# Out:
# 36.85823043357163

# %%
round(data_pd[data_pd['sex'] == 'Female']['age'].mean(), 2)
# Out:
# 36.86

# %% [markdown]
# # 6.Правда ли, что люди, которые получают больше 50k, имеют как минимум высшее образование? (признак education равен Bachelors, Prof-school, Assoc-acdm, Assoc-voc, Masters или Doctorate)

# %%
data.head_sl(14)
# Out:
# <=50  :  24720
# >50  :  7841
# 2

# %%
data.head_sl(3)
# Out:
# Bachelors  :  5355
# HS-grad  :  10501
# 11th  :  1175
# Masters  :  1723
# 9th  :  514
# Some-college  :  7291
# Assoc-acdm  :  1067
# Assoc-voc  :  1382
# 7th-8th  :  646
# Doctorate  :  413
# Prof-school  :  576
# 5th-6th  :  333
# 10th  :  933
# 1st-4th  :  168
# Preschool  :  51
# 12th  :  433
# 16

# %%
data.zapros_in_data("k:'3'",data.id_array_individual[14]['>50'])
# Out:
# {'HS-grad': (1675,
#   [[7, 14],
#    [67, 14],
#    [84, 14],
#    [86, 14],
#    [105, 14],
#    [112, 14],
#    [154, 14],
#    [208, 14],
#    [211, 14],
#    [246, 14],
#    [255, 14],
#    [267, 14],
#    [269, 14],
#    [270, 14],
#    [302, 14],
#    [303, 14],
#    [342, 14],
#    [355, 14],
#    [390, 14],
#    [428, 14],
#    [452, 14],
#    [454, 14],
#    [521, 14],
#    [581, 14],
#    [626, 14],
#    [659, 14],
#    [667, 14],
#    [674, 14],
#    [682, 14],
#    [723, 14],
#    [746, 14],
#    [756, 14],
#    [758, 14],
#    [761, 14],
#    [794, 14],
#    [805, 14],
#    [819, 14],
#    [825, 14],
#    [844, 14],
#    [857, 14],
#    [878, 14],
#    [917, 14],
#    [935, 14],
#    [942, 14],
#    [950, 14],
#    [970, 14],
#    [984, 14],
#    [993, 14],
#    [995, 14],
#    [1002, 14],
#    [1007, 14],
#    [1008, 14],
#    [1012, 14],
#    [1027, 14],
#    [1059, 14],
#    [1071, 14],
#    [1072, 14],
#    [1098, 14],
#    [1126, 14],
#    [1137, 14],
# ...

# %%
data.head_sl(data.zapros_data["k:'3'"])
# Out:
# HS-grad  :  1675
# Masters  :  959
# Bachelors  :  2221
# Some-college  :  1387
# Assoc-voc  :  361
# Doctorate  :  306
# Prof-school  :  423
# Assoc-acdm  :  265
# 7th-8th  :  40
# 12th  :  33
# 10th  :  62
# 11th  :  60
# 9th  :  27
# 5th-6th  :  16
# 1st-4th  :  6
# 15

# %%
data_pd[data_pd['salary'] == '>50K']['education'].unique() # нет
# Out:
# array(['HS-grad', 'Masters', 'Bachelors', 'Some-college', 'Assoc-voc',
#        'Doctorate', 'Prof-school', 'Assoc-acdm', '7th-8th', '12th',
#        '10th', '11th', '9th', '5th-6th', '1st-4th'], dtype=object)

# %% [markdown]
# # 7. Каков максимальный возраст мужчин расы Amer-Indian-Eskimo?

# %%
data.head_sl(8)
# Out:
# White  :  27816
# Black  :  3124
# Asian-Pac-Islander  :  1039
# Amer-Indian-Eskimo  :  311
# Other  :  271
# 5

# %%
data.zapros_in_data("k:'0'",data.id_array_individual[8]['Amer-Indian-Eskimo'])
# Out:
# {'28': (310, [[4, 9], [66, 9], [92, 9], [113, 9], [130, 9], [163, 9], [401, 9], [408, 9], [525, 9], [781, 9], [892, 9], [971, 9], [1157, 9], [1272, 9], [1311, 9], [1472, 9], [1637, 9], [1932, 9], [1967, 9], [1987, 9], [2001, 9], [2084, 9], [2130, 9], [2518, 9], [2639, 9], [2649, 9], [2725, 9], [2838, 9], [2853, 9], [2857, 9], [2881, 9], [2928, 9], [2984, 9], [3586, 9], [3729, 9], [4002, 9], [4037, 9], [4084, 9], [4142, 9], [4294, 9], [4340, 9], [4528, 9], [4835, 9], [4939, 9], [4961, 9], [5003, 9], [5123, 9], [5208, 9], [5304, 9], [5338, 9], [5452, 9], [5502, 9], [5591, 9], [5616, 9], [5720, 9], [6143, 9], [6162, 9], [6398, 9], [6521, 9], [6650, 9], [6726, 9], [6772, 9], [6788, 9], [7075, 9], [7131, 9], [7174, 9], [7322, 9], [7713, 9], [7795, 9], [7841, 9], [8275, 9], [8312, 9], [8408, 9], [8530, 9], [8673, 9], [8928, 9], [8985, 9], [9040, 9], [9042, 9], [9045, 9], [9119, 9], [9153, 9], [9210, 9], [9699, 9], [9729, 9], [9961, 9], [9984, 9], [10070, 9], [10121, 9], [10154, 9], [10168,
# ...

# %%
data.head_sl(data.zapros_data["k:'0'"])
# Out:
# 28  :  310
# 37  :  229
# 49  :  171
# 31  :  282
# 23  :  359
# 43  :  229
# 54  :  105
# 59  :  94
# 19  :  356
# 44  :  202
# 25  :  313
# 18  :  268
# 47  :  214
# 53  :  136
# 46  :  228
# 30  :  273
# 48  :  171
# 20  :  363
# 17  :  186
# 36  :  287
# 21  :  329
# 24  :  305
# 27  :  294
# 45  :  222
# 34  :  257
# 33  :  255
# 68  :  42
# 66  :  48
# 41  :  233
# 38  :  236
# 40  :  263
# 26  :  290
# 42  :  228
# 58  :  105
# 35  :  246
# 50  :  156
# 60  :  79
# 75  :  14
# 65  :  57
# 32  :  255
# 22  :  342
# 39  :  256
# 29  :  271
# 62  :  88
# 57  :  91
# 67  :  52
# 74  :  19
# 72  :  25
# 69  :  33
# 55  :  137
# 52  :  134
# 70  :  28
# 56  :  106
# 61  :  79
# 51  :  163
# 78  :  7
# 63  :  64
# 90  :  14
# 64  :  70
# 73  :  22
# 71  :  26
# 76  :  16
# 81  :  9
# 79  :  5
# 83  :  1
# 77  :  9
# 80  :  5
# 84  :  4
# 82  :  2
# 85  :  1
# 88  :  1
# 86  :  1
# 72

# %%
data.zapros_in_data("max:'0'",data.zapros_data["k:'0'"])
# Out:
# 'Max = 90 - 14'

# %%
for (race, sex), sub_df in pd.groupby(data_pd, ['race', 'sex']):
    print("Раса: {0}, пол: {1}".format(race, sex))
    print(sub_df['age'].describe())
# Out:
# Раса: Amer-Indian-Eskimo, пол: Female
# count    119.000000
# mean      37.117647
# std       13.114991
# min       17.000000
# 25%       27.000000
# 50%       36.000000
# 75%       46.000000
# max       80.000000
# Name: age, dtype: float64
# Раса: Amer-Indian-Eskimo, пол: Male
# count    192.000000
# mean      37.208333
# std       12.049563
# min       17.000000
# 25%       28.000000
# 50%       35.000000
# 75%       45.000000
# max       82.000000
# Name: age, dtype: float64
# Раса: Asian-Pac-Islander, пол: Female
# count    346.000000
# mean      35.089595
# std       12.300845
# min       17.000000
# 25%       25.000000
# 50%       33.000000
# 75%       43.750000
# max       75.000000
# Name: age, dtype: float64
# Раса: Asian-Pac-Islander, пол: Male
# count    693.000000
# mean      39.073593
# std       12.883944
# min       18.000000
# 25%       29.000000
# 50%       37.000000
# 75%       46.000000
# max       90.000000
# Name: age, dtype: float64
# Раса: Black, пол: Female
# ...

# %% [markdown]
# # 8. Среди кого больше доля зарабатывающих много (>50K): среди женатых или холостых мужчин (признак marital-status для женатых равен Married-civ-spouse, Married-spouse-absent или Married-AF-spouse)?

# %%
data.head_sl(5)
# Out:
# Never-married  :  10683
# Married-civ-spouse  :  14976
# Divorced  :  4443
# Married-spouse-absent  :  418
# Separated  :  1025
# Married-AF-spouse  :  23
# Widowed  :  993
# 7

# %%
data_pd[(data_pd['sex'] == 'Male') &
     (data_pd['marital-status'].isin(['Never-married', 
                                   'Separated', 'Divorced']))]['salary'].value_counts()
# Out:
# <=50K    7423
# >50K      658
# Name: salary, dtype: int64

# %%
data_pd[(data_pd['sex'] == 'Male') &
     (data_pd['marital-status'].str.startswith('Married'))]\
    ['salary'].value_counts()
# Out:
# <=50K    7576
# >50K     5965
# Name: salary, dtype: int64

# %%
data_pd['marital-status'].value_counts()
# Out:
# Married-civ-spouse       14976
# Never-married            10683
# Divorced                  4443
# Separated                 1025
# Widowed                    993
# Married-spouse-absent      418
# Married-AF-spouse           23
# Name: marital-status, dtype: int64

# %% [markdown]
# # 10. Каково среднее время работы (hours-per-week) зарабатывающих мало и много (salary) для Японии?

# %%
data.head_sl(13)
# Out:
# United-States  :  29170
# Cuba  :  95
# Jamaica  :  81
# India  :  100
# ?  :  583
# Mexico  :  643
# South  :  80
# Puerto-Rico  :  114
# Honduras  :  13
# England  :  90
# Canada  :  121
# Germany  :  137
# Iran  :  43
# Philippines  :  198
# Italy  :  73
# Poland  :  60
# Columbia  :  59
# Cambodia  :  19
# Thailand  :  18
# Ecuador  :  28
# Laos  :  18
# Taiwan  :  51
# Haiti  :  44
# Portugal  :  37
# Dominican-Republic  :  70
# El-Salvador  :  106
# France  :  29
# Guatemala  :  64
# China  :  75
# Japan  :  62
# Yugoslavia  :  16
# Peru  :  31
# Outlying-US(Guam-USVI-etc)  :  14
# Scotland  :  12
# Trinadad&Tobago  :  19
# Greece  :  29
# Nicaragua  :  34
# Vietnam  :  67
# Hong  :  20
# Ireland  :  24
# Hungary  :  13
# Holand-Netherlands  :  1
# 42

# %%
data.zapros_in_data("k:'14'",data.id_array_individual[13]['Japan'])
# Out:
# {'<=50': (38,
#   [[1020, 13],
#    [1119, 13],
#    [1301, 13],
#    [1756, 13],
#    [2096, 13],
#    [2834, 13],
#    [2994, 13],
#    [5012, 13],
#    [5491, 13],
#    [6038, 13],
#    [7245, 13],
#    [7792, 13],
#    [9262, 13],
#    [9452, 13],
#    [12323, 13],
#    [12848, 13],
#    [13244, 13],
#    [13923, 13],
#    [14543, 13],
#    [15177, 13],
#    [16200, 13],
#    [16391, 13],
#    [17142, 13],
#    [18686, 13],
#    [18808, 13],
#    [20936, 13],
#    [23931, 13],
#    [24632, 13],
#    [25696, 13],
#    [25946, 13],
#    [26362, 13],
#    [26862, 13],
#    [27135, 13],
#    [27163, 13],
#    [29393, 13],
#    [31757, 13],
#    [32075, 13],
#    [32376, 13]]),
#  '>50': (24,
#   [[1368, 13],
#    [3064, 13],
#    [5980, 13],
#    [8152, 13],
#    [8237, 13],
#    [9017, 13],
#    [11764, 13],
#    [13229, 13],
#    [14396, 13],
#    [16729, 13],
#    [18414, 13],
#    [18538, 13],
#    [18657, 13],
#    [19743, 13],
#    [20137, 13],
#    [20292, 13],
# ...

# %%
data.head_sl(12)
# Out:
# 40  :  15217
# 13  :  23
# 16  :  205
# 45  :  1824
# 50  :  2819
# 80  :  133
# 30  :  1149
# 35  :  1297
# 60  :  1475
# 20  :  1224
# 52  :  138
# 44  :  212
# 15  :  404
# 25  :  674
# 38  :  476
# 43  :  151
# 55  :  694
# 48  :  517
# 58  :  28
# 32  :  266
# 70  :  291
# 2  :  32
# 22  :  44
# 56  :  97
# 41  :  36
# 28  :  86
# 36  :  220
# 24  :  252
# 46  :  82
# 42  :  219
# 12  :  173
# 65  :  244
# 1  :  20
# 10  :  278
# 34  :  28
# 75  :  66
# 98  :  11
# 33  :  39
# 54  :  41
# 8  :  145
# 6  :  64
# 64  :  14
# 19  :  14
# 18  :  75
# 72  :  71
# 5  :  60
# 9  :  18
# 47  :  49
# 37  :  149
# 21  :  24
# 26  :  30
# 14  :  34
# 4  :  54
# 59  :  5
# 7  :  26
# 99  :  85
# 53  :  25
# 39  :  38
# 62  :  18
# 57  :  17
# 78  :  8
# 90  :  29
# 66  :  17
# 11  :  11
# 49  :  29
# 84  :  45
# 3  :  39
# 17  :  29
# 68  :  12
# 27  :  30
# 85  :  13
# 31  :  5
# 51  :  13
# 77  :  6
# 63  :  10
# 23  :  21
# 87  :  1
# 88  :  2
# 73  :  2
# 89  :  2
# 97  :  2
# 94  :  1
# ...

# %%
data.zapros_in_data("k:'12'",data.zapros_data["k:'14'"]['>50'])
# Out:
# {'40': (10,
#   [[1368, 13],
#    [3064, 13],
#    [8152, 13],
#    [8237, 13],
#    [9017, 13],
#    [16729, 13],
#    [20423, 13],
#    [22174, 13],
#    [26415, 13],
#    [30802, 13]]),
#  '50': (6,
#   [[5980, 13],
#    [11764, 13],
#    [14396, 13],
#    [18414, 13],
#    [19743, 13],
#    [32533, 13]]),
#  '21': (1, [[13229, 13]]),
#  '55': (1, [[18538, 13]]),
#  '84': (1, [[18657, 13]]),
#  '30': (1, [[20137, 13]]),
#  '52': (1, [[20292, 13]]),
#  '45': (1, [[22225, 13]]),
#  '99': (1, [[24483, 13]]),
#  '65': (1, [[31830, 13]])}

# %%
data.zapros_data["k:'12'"]
# Out:
# {'40': (10,
#   [[1368, 13],
#    [3064, 13],
#    [8152, 13],
#    [8237, 13],
#    [9017, 13],
#    [16729, 13],
#    [20423, 13],
#    [22174, 13],
#    [26415, 13],
#    [30802, 13]]),
#  '50': (6,
#   [[5980, 13],
#    [11764, 13],
#    [14396, 13],
#    [18414, 13],
#    [19743, 13],
#    [32533, 13]]),
#  '21': (1, [[13229, 13]]),
#  '55': (1, [[18538, 13]]),
#  '84': (1, [[18657, 13]]),
#  '30': (1, [[20137, 13]]),
#  '52': (1, [[20292, 13]]),
#  '45': (1, [[22225, 13]]),
#  '99': (1, [[24483, 13]]),
#  '65': (1, [[31830, 13]])}

# %%
data.zapros_in_data("p:'2'",data.zapros_data["k:'12'"])
# Out:
# 47.958333333333336

# %%
data.zapros_in_data("k:'12'|1",data.zapros_data["k:'14'"]['<=50'])
# Out:
# {'50': (2, [[1020, 13], [27163, 13]]),
#  '40': (21,
#   [[1119, 13],
#    [1301, 13],
#    [2834, 13],
#    [5491, 13],
#    [7245, 13],
#    [7792, 13],
#    [9262, 13],
#    [12848, 13],
#    [13923, 13],
#    [14543, 13],
#    [16391, 13],
#    [17142, 13],
#    [18808, 13],
#    [23931, 13],
#    [24632, 13],
#    [25696, 13],
#    [26362, 13],
#    [26862, 13],
#    [27135, 13],
#    [32075, 13],
#    [32376, 13]]),
#  '60': (5, [[1756, 13], [2994, 13], [6038, 13], [25946, 13], [29393, 13]]),
#  '16': (1, [[2096, 13]]),
#  '30': (3, [[5012, 13], [9452, 13], [12323, 13]]),
#  '45': (1, [[13244, 13]]),
#  '42': (1, [[15177, 13]]),
#  '15': (1, [[16200, 13]]),
#  '65': (1, [[18686, 13]]),
#  '10': (1, [[20936, 13]]),
#  '35': (1, [[31757, 13]])}

# %%
data.zapros_in_data("p:'3'",data.zapros_data["k:'12'|1"])
# Out:
# 41.0

# %%
for (country, salary), sub_df in data_pd.groupby(['native-country', 
                                               'salary']):
    print(country, salary, round(sub_df['hours-per-week'].mean(), 2))
# Out:
# ? <=50K 40.16
# ? >50K 45.55
# Cambodia <=50K 41.42
# Cambodia >50K 40.0
# Canada <=50K 37.91
# Canada >50K 45.64
# China <=50K 37.38
# China >50K 38.9
# Columbia <=50K 38.68
# Columbia >50K 50.0
# Cuba <=50K 37.99
# Cuba >50K 42.44
# Dominican-Republic <=50K 42.34
# Dominican-Republic >50K 47.0
# Ecuador <=50K 38.04
# Ecuador >50K 48.75
# El-Salvador <=50K 36.03
# El-Salvador >50K 45.0
# England <=50K 40.48
# England >50K 44.53
# France <=50K 41.06
# France >50K 50.75
# Germany <=50K 39.14
# Germany >50K 44.98
# Greece <=50K 41.81
# Greece >50K 50.62
# Guatemala <=50K 39.36
# Guatemala >50K 36.67
# Haiti <=50K 36.33
# Haiti >50K 42.75
# Holand-Netherlands <=50K 40.0
# Honduras <=50K 34.33
# Honduras >50K 60.0
# Hong <=50K 39.14
# Hong >50K 45.0
# Hungary <=50K 31.3
# Hungary >50K 50.0
# India <=50K 38.23
# India >50K 46.48
# Iran <=50K 41.44
# Iran >50K 47.5
# Ireland <=50K 40.95
# Ireland >50K 48.0
# Italy <=50K 39.62
# Italy >50K 45.4
# Jamaica <=50K 38.24
# Jamaica >50K 41.1
# ...

# %% [markdown]
# # 4-5. Каковы средние и среднеквадратичные отклонения возраста тех, кто получает более 50K в год (признак salary) и тех, кто получает менее 50K в год?

# %%
ages1 = data_pd[data_pd['salary'] == '>50K']['age']
ages2 = data_pd[data_pd['salary'] == '<=50K']['age']
print("Средний возраст богатых: {0} +- {1} лет, небогатых - {2} +- {3} лет.".format(
    round(ages1.mean()), round(ages1.std(), 1),
    round(ages2.mean()), round(ages2.std(), 1)))
# Out:
# Средний возраст богатых: 44 +- 10.5 лет, небогатых - 37 +- 14.0 лет.
